# %% [markdown]
# # function calling

# %% [markdown]
# ### Calling a function inside class

# %%
=> The self parameter is a reference to the current instance of the class, 
    and is used to access variables that belongs to the class.

=> It does not have to be named self , you can call it whatever you like, 
   but it has to be the first parameter of any function in the class.S

# %%
class Person:
    def __init__(self, name, age, sal):
        self.name = name
        self.age = age
        self.sal = sal
        
    def person_age_check(self):
        if self.age < 25:
            print(self.name)
            
    p1 = Person('Naveen', 24, 23000)
    p1.person_age_check()
# Out:
# Naveen

# %% [markdown]
# ### Calling a function out of calss

# %%
class Person:
    def __init__(self, name, age, sal):
        self.name = name
        self.age = age
        self.sal = sal
        
    def person_age_check(self):
        if self.age < 25:
            print(self.age)
            
p2 = Person('Naveen', 24, 23000)
p2.person_age_check()
# Out:
# 24

# %%
=> We can not call this functions without create object inside and outside of class

# %%
class Person:
    def __init__(self, name, age, sal):
        self.name = name
        self.age = age
        self.sal = sal
        
    def person_age_check(self):
        if self.age < 25:
            print(self.age)
            
# Calling the function outside of class without obj creation           
person_age_check()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a57e59ff0915> in <module>
#       9             print(self.age)
#      10
# ---> 11 person_age_check()
#
# NameError: name 'person_age_check' is not defined

# %%
class Person:
    def __init__(self, name, age, sal):
        self.name = name
        self.age = age
        self.sal = sal
        
    def person_age_check(self):
        if self.age < 25:
            print(self.age)
            
    # Calling the function in-side of class without obj creation           
    person_age_check()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-6a309aed541d> in <module>
# ----> 1 class Person:
#       2     def __init__(self, name, age, sal):
#       3         self.name = name
#       4         self.age = age
#       5         self.sal = sal
#
# <ipython-input-11-6a309aed541d> in Person()
#      10
#      11     # Calling the function outside of class without obj creation
# ---> 12     person_age_check()
#
# TypeError: person_age_check() missing 1 required positional argument: 'self'
